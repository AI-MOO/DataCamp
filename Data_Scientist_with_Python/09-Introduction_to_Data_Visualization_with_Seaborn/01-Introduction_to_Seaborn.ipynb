# %% [markdown]
# ## `Section 01: Introduction to Seaborn`

# %% [markdown]
# ### 01- Making a scatter plot with lists
# * Import Matplotlib and Seaborn using the standard naming convention.

# %%
# Import Matplotlib and Seaborn
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
with open("datasets/gdp_phones.csv", "rb") as f1:
    gdp_phones = pd.read_csv(f1)
    gdp = gdp_phones["gdp"].to_list()
    phones = gdp_phones["phones"].to_list()
    percent_literate = gdp_phones["percent_literate"].to_list()

# %% [markdown]
# * Create a scatter plot of GDP (`gdp`) vs. number of phones per 1000 people (`phones`).
# * Display the plot.

# %%
# Create scatter plot with GDP on the x-axis and number of phones on the y-axis
sns.scatterplot(x=gdp, y=phones)
plt.show()

# %% [markdown]
# * Change the scatter plot so it displays the percent of the population that can read and write (`percent_literate`) on the y-axis.

# %%
# Import Matplotlib and Seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# Change this scatter plot to have percent literate on the y-axis
sns.scatterplot(x=gdp, y=percent_literate)

# Show plot
plt.show()

# %% [markdown]
# ### 02-Making a count plot with a list
# * Import Matplotlib and Seaborn using the standard naming conventions.
# * Use Seaborn to create a count plot with `region` on the y-axis.
# * Display the plot.

# %%
with open("datasets/region.csv", "rb") as f1:
    region_df = pd.read_csv(f1)
    region = region_df["region"]

# %%
# Import Matplotlib and Seaborn
import matplotlib.pyplot as plt 
import seaborn as sns


# Create count plot with region on the y-axis
sns.countplot(y=region)

# Show plot
plt.show()

# %% [markdown]
# ### 03- "Tidy" vs. "untidy" data
# * Read the csv file located at `csv_filepath` into a DataFrame named `df`.
# * Print the head of `df` to show the first five rows.

# %%
# Import pandas
import pandas as pd

# Create a DataFrame from csv file
csv_filepath = "datasets/1.2.1_example_csv.csv"
df = pd.read_csv(csv_filepath)

# Print the head of df
print(df.head())

# untidy data
# Out:
#   Unnamed: 0               How old are you?
# 0     Marion                             12
# 1      Elroy                             16
# 2        NaN  What is your favorite animal?
# 3     Marion                            dog
# 4      Elroy                            cat

# %% [markdown]
# ### 04-Making a count plot with a DataFrame
#
# * Import Matplotlib, pandas, and Seaborn using the standard names.
# * Create a DataFrame named `df` from the csv file located at `csv_filepath`.
# * Use the `countplot()` function with the `x=` and `data=`arguments to create a count plot with the `"Spiders"` column values on the x-axis.
# * Display the plot.

# %%
csv_filepath = "datasets/young-people-survey-responses.csv"

# Import Matplotlib, pandas, and Seaborn
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 


# Create a DataFrame from csv file
df = pd.read_csv(csv_filepath)

# Create a count plot with "Spiders" on the x-axis
sns.countplot(x="Spiders", data=df)

# Display the plot
plt.show()

# %% [markdown]
# ### 05-Hue and scatter plots
# * Create a scatter plot with `"absences"` on the x-axis and final grade (`"G3"`) on the y-axis using the DataFrame `student_data`. Color the plot points based on `"location"` (urban vs. rural).

# %%
with open("datasets/student_data.csv", "rb") as f1: 
    student_data = pd.read_csv(f1, index_col=0)
student_data
# Out:
#     school sex  age famsize Pstatus  Medu  Fedu  traveltime  failures  \
# 0       GP   F   18     GT3       A     4     4           2         0
# 1       GP   F   17     GT3       T     1     1           1         0
# 2       GP   F   15     LE3       T     1     1           1         3
# 3       GP   F   15     GT3       T     4     2           1         0
# 4       GP   F   16     GT3       T     3     3           1         0
# ..     ...  ..  ...     ...     ...   ...   ...         ...       ...
# 390     MS   M   20     LE3       A     2     2           1         2
# 391     MS   M   17     LE3       T     3     1           2         0
# 392     MS   M   21     GT3       T     1     1           1         3
# 393     MS   M   18     LE3       T     3     2           3         0
# 394     MS   M   19     LE3       T     1     1           1         0
#
#     schoolsup  ... goout Dalc Walc health absences  G1  G2  G3  location  \
# 0         yes  ...     4    1    1      3        6   5   6   6     Urban
# 1          no  ...     3    1    1      3        4   5   5   6     Urban
# 2         yes  ...     2    2    3      3       10   7   8  10     Urban
# 3          no  ...     2    1    1      5        2  15  14  15     Urban
# 4          no  ...     2    1    2      5        4   6  10  10     Urban
# ..        ...  ...   ...  ...  ...    ...      ...  ..  ..  ..       ...
# 390        no  ...     4    4    5      4       11   9   9   9     Urban
# 391        no  ...     5    3    4      2        3  14  16  16     Urban
# 392        no  ...     3    3    3      3        3  10   8   7     Rural
# 393        no  ...     1    3    4      5        0  11  12  10     Rural
# 394        no  ...     3    3    3      5        5   8   9   9     Urban
#
#         study_time
# 0     2 to 5 hours
# 1     2 to 5 hours
# 2     2 to 5 hours
# 3    5 to 10 hours
# 4     2 to 5 hours
# ..             ...
# 390   2 to 5 hours
# 391       <2 hours
# 392       <2 hours
# 393       <2 hours
# 394       <2 hours
#
# [395 rows x 29 columns]

# %%
# Import Matplotlib and Seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# Create a scatter plot of absences vs. final grade
sns.scatterplot(x="absences", y="G3", data=student_data, hue="location")

# Show plot
plt.show()

# %% [markdown]
# * Make `"Rural"` appear before `"Urban"` in the plot legend.

# %%
# Import Matplotlib and Seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# Change the legend order in the scatter plot
sns.scatterplot(x="absences", y="G3", 
                data=student_data, 
                hue="location", 
                hue_order=["Rural", "Urban"])

# Show plot
plt.show()

# %% [markdown]
# ### 06-Hue and count plots
# * Fill in the `palette_colors` dictionary to map the `"Rural"` location value to the color `"green"` and the `"Urban"` location value to the color `"blue"`.
# * Create a count plot with `"school"` on the x-axis using the `student_data` DataFrame.
#     * Add subgroups to the plot using `"location"` variable and use the `palette_colors` dictionary to make the location subgroups green and blue.

# %%
# Import Matplotlib and Seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# Create a dictionary mapping subgroup values to colors
palette_colors = {"Rural": "green", "Urban": "blue"}

# Create a count plot of school with location subgroups
sns.countplot(x="school", data=student_data, hue="location", palette=palette_colors)

# Display plot
plt.show()

# %% [markdown]
# ==================================
# ### `The End`
# ==================================
