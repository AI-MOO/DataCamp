# %% [markdown]
# ## `Section 03: Additional Plot Types`

# %% [markdown]
# ### 01- stripplot() and swarmplot()
# * Create a `stripplot` of the `Award_Amount` with the `Model Selected` on the y axis with `jitter` enabled.

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 

with open("datasets/schoolimprovement2010grants.csv", "rb") as f1:
    df = pd.read_csv(f1)
df.head(7)
# Out:
#    Unnamed: 0                        School Name      City State  \
# 0           0  HOGARTH KINGEEKUK MEMORIAL SCHOOL  SAVOONGA    AK
# 1           1                    AKIACHAK SCHOOL  AKIACHAK    AK
# 2           2                     GAMBELL SCHOOL   GAMBELL    AK
# 3           3               BURCHELL HIGH SCHOOL   WASILLA    AK
# 4           4                       AKIAK SCHOOL     AKIAK    AK
# 5           5                     MIDVALLEY HIGH   WASILLA    AK
# 6           6                    TULUKSAK SCHOOL  TULUKSAK    AK
#
#                                District Name  Model Selected  Award_Amount  \
# 0              BERING STRAIT SCHOOL DISTRICT  Transformation        471014
# 1                     YUPIIT SCHOOL DISTRICT  Transformation        520579
# 2              BERING STRAIT SCHOOL DISTRICT  Transformation        449592
# 3  MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT  Transformation        641184
# 4                     YUPIIT SCHOOL DISTRICT  Transformation        399686
# 5  MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT         Restart        697703
# 6                     YUPIIT SCHOOL DISTRICT  Transformation        427658
#
#   Region
# 0   West
# 1   West
# 2   West
# 3   West
# 4   West
# 5   West
# 6   West

# %%
# Create the stripplot
fig, ax = plt.subplots(figsize=(15,5))

sns.stripplot(data=df,
         x='Award_Amount',
         y='Model Selected',
         jitter=True,
         ax=ax)

plt.show()

# %% [markdown]
# * Create a `swarmplot()` of the same data, but also include the `hue` by `Region`.

# %%
# Create and display a swarmplot with hue set to the Region
fig, ax = plt.subplots(figsize=(15,5))

sns.swarmplot(data=df,
         x='Award_Amount',
         y='Model Selected',
         hue='Region',
         ax=ax)

plt.show()
# Out:
# C:\Users\MOHAMAD\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 10.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### 02- boxplots, violinplots and lvplots
# * Create and display a `boxplot` of the data with `Award_Amount` on the x axis and `Model Selected` on the y axis.

# %%
# Create a boxplot
fig, ax = plt.subplots(figsize=(10,5))

sns.boxplot(data=df,
         x='Award_Amount',
         y='Model Selected',
         ax=ax)

plt.show()
plt.clf()

# %% [markdown]
# * Create and display a similar `violinplot` of the data, but use the `husl` palette for colors.

# %%
# Create a violinplot with the husl palette
fig, ax = plt.subplots(figsize=(10,5))

sns.violinplot(data=df,
         x='Award_Amount',
         y='Model Selected',
         palette='husl', 
         ax=ax)

plt.show()
plt.clf()

# %% [markdown]
# * Create and display an `lvplot` using the `Paired` palette and the `Region` column as the `hue`.

# %%
# Create a lvplot with the Paired palette and the Region column as the hue
''' 
# old version of seaborn ! 
sns.lvplot(data=df,
         x='Award_Amount',
         y='Model Selected',
         palette='Paired',
         hue='Region')

plt.show()
plt.clf()

'''

# %%
# Create a lvplot (boxenplot) with the Paired palette and the Region column as the hue
fig, ax = plt.subplots(figsize=(12,8))

sns.boxenplot(data=df,
         x='Award_Amount',
         y='Model Selected',
         palette='Paired',
         hue='Region', 
         ax=ax)

plt.show()
plt.clf()

# %%
# Show a countplot with the number of models used with each region a different color
sns.countplot(data=df,
         y="Model Selected",
         hue="Region")

plt.show()
plt.clf()

# %% [markdown]
# * Create a `pointplot` with the `df` dataframe and `Model Selected` on the x-axis and `Award_Amount` on the y-axis.
# * Use a `capsize` in the `pointplot` in order to add caps to the error bars.

# %%
# Create a pointplot and include the capsize in order to show caps on the error bars
sns.pointplot(data=df,
         y='Award_Amount',
         x='Model Selected',
         capsize=.1)

plt.show()
plt.clf()

# %% [markdown]
# * Create a `barplot` with the same data on the x and y axis and change the color of each bar based on the `Region` column.

# %%
# Create a barplot with each Region shown as a different color
sns.barplot(data=df,
         y='Award_Amount',
         x='Model Selected',
         hue='Region')

plt.show()
plt.clf()

# %% [markdown]
# ### 03-Regression and residual plots
# * Plot a regression plot comparing `Tuition` and average SAT scores(`SAT_AVG_ALL`).
# * Make sure the values are shown as green triangles.

# %%
with open("datasets/US_Department_of_Educatio.csv", "rb") as file:
    df = pd.read_csv(file, index_col=0)

df.head(3)
# Out:
#                                 INSTNM   OPEID  REGION  SAT_AVG_ALL  PCTPELL  \
# 0             Alabama A & M University  100200       5          850   0.7249
# 1  University of Alabama at Birmingham  105200       5         1147   0.3505
# 2  University of Alabama in Huntsville  105500       5         1221   0.3179
#
#    PCTFLOAN  ADM_RATE_ALL     UG  AVGFACSAL COMPL_RPY_5YR_RT DEBT_MDN  \
# 0    0.8159      0.653841   4380       7017      0.477631579    14600
# 1    0.5218      0.604275  10331      10221      0.673230442    14250
# 2    0.4589      0.811971   5220       9514      0.762222222    15000
#
#    MEDIAN_HH_INC  Tuition
# 0       49720.22    13435
# 1       55735.22    16023
# 2       58688.62    18661

# %%
# Display a regression plot for Tuition
sns.regplot(data=df,
         y='Tuition',
         x="SAT_AVG_ALL",
         marker='^',
         color='g')

plt.show()
plt.clf()

# %% [markdown]
# * Use a residual plot to determine if the relationship looks linear.

# %%
# Display the residual plot
sns.residplot(data=df,
          y='Tuition',
          x="SAT_AVG_ALL",
          color='g')

plt.show()
plt.clf()

# %% [markdown]
# ### 04-Regression plot parameters
# * Plot a regression plot of `Tuition` and `PCTPELL`.

# %%
# Plot a regression plot of Tuition and the Percentage of Pell Grants
sns.regplot(data=df,
            y='Tuition',
            x="PCTPELL")

plt.show()
plt.clf()

# %%
# Create another plot that estimates the tuition by PCTPELL
sns.regplot(data=df,
            y='Tuition',
            x="PCTPELL",
            x_bins=5)

plt.show()
plt.clf()

# %% [markdown]
# * Create a final regression plot that includes a 2nd `order` polynomial regression line.

# %%
# The final plot should include a line using a 2nd order polynomial
sns.regplot(data=df,
            y='Tuition',
            x="PCTPELL",
            x_bins=5,
            order=2)

plt.show()
plt.clf()

# %% [markdown]
# ### 05-Binning data
# * Create a `regplot` of `Tuition` and `UG` and set the `fit_reg` parameter to `False` to disable the regression line.

# %%
# Create a scatter plot by disabling the regression line
sns.regplot(data=df,
            y='Tuition',
            x="UG",
            fit_reg=False)

plt.show()
plt.clf()

# %% [markdown]
# * Create another plot with the `UG` data divided into 5 bins.

# %%
# Create a scatter plot and bin the data into 5 bins
sns.regplot(data=df,
            y='Tuition',
            x="UG",
            x_bins=5)

plt.show()
plt.clf()

# %% [markdown]
# * Create a `regplot()` with the data divided into 8 bins.

# %%
# Create a regplot and bin the data into 8 bins
sns.regplot(data=df,
         y='Tuition',
         x="UG",
         x_bins=8)

plt.show()
plt.clf()

# %% [markdown]
# ### 06-Creating heatmaps
#
# * Use pandas' `crosstab()` function to build a table of visits by `Group` and `Year`.
# * Print the `pd_crosstab` DataFrame.
# * Plot the data using Seaborn's `heatmap()`.

# %%
with open("datasets/GoogleKnowlege_Occupation.csv", "rb") as file:
    df = pd.read_csv(file, index_col=0)
df
# Out:
#       YEAR GoogleKnowlege_Occupation       Show   Group        Raw_Guest_List
# 0     1999                     actor  1/11/1999  Acting        Michael J. Fox
# 1     1999                  Comedian  1/12/1999  Comedy       Sandra Bernhard
# 2     1999        television actress  1/13/1999  Acting         Tracey Ullman
# 3     1999              film actress  1/14/1999  Acting      Gillian Anderson
# 4     1999                     actor  1/18/1999  Acting      David Alan Grier
# ...    ...                       ...        ...     ...                   ...
# 2688  2015                biographer  7/29/2015   Media  Doris Kearns Goodwin
# 2689  2015                  director  7/30/2015   Media          J. J. Abrams
# 2690  2015         stand-up comedian   8/3/2015  Comedy           Amy Schumer
# 2691  2015                     actor   8/4/2015  Acting           Denis Leary
# 2692  2015                  comedian   8/5/2015  Comedy            Louis C.K.
#
# [2693 rows x 5 columns]

# %%
# Create a crosstab table of the data
pd_crosstab = pd.crosstab(df["Group"], df["YEAR"])
print(pd_crosstab)

# Plot a heatmap of the table
sns.heatmap(pd_crosstab)

# Rotate tick marks for visibility
plt.yticks(rotation=0)
plt.xticks(rotation=90)

plt.show()
# Out:
# YEAR            1999  2000  2001  2002  2003  2004  2005  2006  2007  2008  \
# Group
# Academic           0     0     2     0     4     1    12     9    13     5
# Acting           108   100    92    84    74    51    44    44    25    26
# Advocacy           0     1     0     1     0     4     0     0     2     3
# Athletics          0     3     1     2     0     2     2     5     4     1
# Business           0     1     0     0     0     2     1     1     2     1
# Clergy             0     0     0     1     1     1     0     0     1     0
# Comedy            25    12    11     5    12     7     5     8     9     7
# Consultant         0     0     0     0     1     4     1     4     2     3
# Government         0     0     2     1     2     3     1     3     1     0
# Media             11    21    31    42    41    45    54    47    47    77
# Military           0     0     0     0     0     0     1     1     3     1
# Misc               0     0     2     1     1     0     4     3     2     2
# Musician          17    13    11    10     7     5    11     6     2     1
# Political Aide     0     1     1     2     1     2     3     3     2     6
# Politician         2    13     3     8    14    32    22    25    21    27
# Science            0     0     0     0     1     2     1     1     4     1
#
# YEAR            2009  2010  2011  2012  2013  2014  2015
# Group
# Academic          11     8    10     8     8    10     2
# Acting            22    45    42    33    60    47    33
# Advocacy           1     1     1     2     2     3     3
# Athletics          7     5     2     7     4     4     3
# Business           4     2     3     3     3     1     1
# Clergy             1     0     1     2     0     0     0
# Comedy             7     7     7     6     6     9     7
# Consultant         2     1     0     0     0     0     0
# Government         5     3     3     3     7     6     0
# Media             59    50    51    52    51    53    24
# Military           1     2     3     1     1     1     1
# Misc               5     4     5     6     2     5     3
# Musician           5     6     6     5     5     8     5
# Political Aide     3     2     1     1     3     2     3
# Politician        26    25    23    29    11    13    14
# Science            4     3     5     2     2     1     1

# %% [markdown]
# ### 07-Customizing heatmaps
# * Create a crosstab table of `Group` and `YEAR`
# * Create a heatmap of the data using the `BuGn` palette
# * Disable the `cbar` and increase the `linewidth` to 0.3

# %%
# Create the crosstab DataFrame
pd_crosstab = pd.crosstab(df["Group"], df["YEAR"])

# Plot a heatmap of the table with no color bar and using the BuGn palette
sns.heatmap(pd_crosstab, cbar=False, cmap="BuGn", linewidths=0.3)

# Rotate tick marks for visibility
plt.yticks(rotation=0)
plt.xticks(rotation=90)

#Show the plot
plt.show()
plt.clf()

# %% [markdown]
# ==================================
# ### `The End`
# ==================================
